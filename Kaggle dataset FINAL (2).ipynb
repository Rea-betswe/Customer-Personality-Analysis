# %% [markdown]
# <center><img src="https://i.postimg.cc/VL0pG6WH/digital-marketing-customer-service-retail-png-favpng-R0c-Hm-Ye-VEu-Vwfii-Mpw-LJEwzb-D-removebg-preview.png">

# %% [markdown]
# <a id="setup"></a>
# <h1><b><p style="background-image: url(https://i.postimg.cc/g2QJ9rCX/Black-and-Beige-Simple-Coming-Soon-Banner.png);font-family:tahoma;font-size:120%;color:White;text-align:center;border-radius:15px 50px; padding:7px; border:solid 2px #09375b; box-shadow: 10px 10px 10px #042b4c">Step 1 | Python Libraries</p></b></h1>

# %% [markdown]
# <a id="import"></a>
# <h2><b><span style="color:Green">🛒 Step 1.1 | </span><span style="color:Teal">Import Libraries</span></b></h2>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
import pmdarima as pm
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

from sklearn.model_selection import train_test_split 
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingRegressor
import xgboost as xgb
from xgboost import XGBClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, ExtraTreesClassifier
from sklearn.metrics import classification_report
from keras.models import Sequential
from keras.layers import Dense,Dropout
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import RobustScaler, OneHotEncoder 
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import roc_curve, auc
import lime
from lime import lime_tabular
import shap
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

from sklearn.calibration import CalibratedClassifierCV
from implicit.als import AlternatingLeastSquares
from surprise import Dataset, Reader, SVD
from surprise.model_selection import cross_validate
from surprise.model_selection import train_test_split
from surprise import accuracy

import logging 
import implicit
import scipy.sparse as sparse
from implicit.als import AlternatingLeastSquares

from sklearn.compose import ColumnTransformer
from sklearn import metrics
from sklearn.metrics import accuracy_score
from statsmodels.tsa.holtwinters import ExponentialSmoothing
import statsmodels.api as sm
from tabulate import tabulate
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
from prettytable import PrettyTable
import statsmodels.api as sm
from sklearn.preprocessing import StandardScaler
import plotly.express as px
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore", category=UserWarning)
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=RuntimeWarning)

from termcolor import colored


print(colored('\nAll libraries imported succesfully.', 'green'))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 9
#       7 from statsmodels.tsa.arima.model import ARIMA
#       8 from statsmodels.tsa.statespace.sarimax import SARIMAX
# ----> 9 import pmdarima as pm
#      10 from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
#      11 from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
#
# ModuleNotFoundError: No module named 'pmdarima'

# %% [markdown]
# <a id="setup"></a>
# <h1><b><p style="background-image: url(https://i.postimg.cc/g2QJ9rCX/Black-and-Beige-Simple-Coming-Soon-Banner.png);font-family:tahoma;font-size:120%;color:white;text-align:center;border-radius:15px 50px; padding:7px; border:solid 2px #09375b; box-shadow: 10px 10px 10px #042b4c">Step 2 | Data Preparation</p></b></h1>

# %% [markdown]
# <a id="import"></a>
# <h2><b><span style="color:green">🛒Step 2.1 | </span><span style="color:teal">Load Data</span></b></h2>

# %%
df = pd.read_csv('data.csv', encoding='latin1')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# <h2><b><span style="color:Teal"> Check Data Types</span></b></h2>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# 1. Convert 'InvoiceDate' to datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# 2. Convert 'CustomerID' to string (categorical IDs, not floats)
df['CustomerID'] = df['CustomerID'].astype('Int64').astype('string')

# 3. Ensure 'Quantity' is integer (already is, but just to be safe)
df['Quantity'] = df['Quantity'].astype('int')

# 4. Ensure 'UnitPrice' is float (already is)
df['UnitPrice'] = df['UnitPrice'].astype('float')

# 5. 'InvoiceNo', 'StockCode', 'Description', 'Country' should be strings
df['InvoiceNo'] = df['InvoiceNo'].astype('string')
df['StockCode'] = df['StockCode'].astype('string')
df['Description'] = df['Description'].astype('string')
df['Country'] = df['Country'].astype('string')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  string
#  1   StockCode    541909 non-null  string
#  2   Description  540455 non-null  string
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  string
#  7   Country      541909 non-null  string
# dtypes: datetime64[ns](1), float64(1), int64(1), string(5)
# memory usage: 33.1 MB

# %% [markdown]
# <h2><b><span style="color:Teal">Check for any null values</span></b></h2>

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %% [markdown]
# ##### Keep only rows with CustomerID, can’t recommend anything to a customer if you don’t know who they are.
# ##### If it’s small (~1k nulls), dropping them is safe.

# %%
# Drop rows with no CustomerID (can't do personalization without it)
df = df.dropna(subset=['CustomerID'])

# Drop rows with no Description (to keep product metadata clean)
df = df.dropna(subset=['Description'])

# Recast CustomerID as string
df['CustomerID'] = df['CustomerID'].astype('Int64').astype('string')

# %%
df.isnull().sum()
# Out:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# dtype: int64

# %% [markdown]
# <h2><b><span style="color:Teal">Check for any duplicates</span></b></h2>

# %%
# Finding duplicate rows 
duplicate_rows = df[df.duplicated(keep=False)]

# Sorting the data by certain columns to see the duplicate rows next to each other
duplicate_rows_sorted = duplicate_rows.sort_values(by=['InvoiceNo', 'StockCode', 'Description', 'CustomerID', 'Quantity'])
duplicate_rows_sorted.head(10)
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country, user_id, item_id, InvoiceDay, Total_Spend, Affordable, TotalPrice]
# Index: []

# %%
# Displaying the number of duplicate rows
print(f"The dataset contains {df.duplicated().sum()} duplicate rows that have to be removed.")

# Removing duplicate rows
df.drop_duplicates(inplace=True)
# Out:
# The dataset contains 5225 duplicate rows that need to be removed.

# %%
print(f"The dataset contains {df.duplicated().sum()} duplicate rows now")
# Out:
# The dataset contains 0 duplicate rows now

# %% [markdown]
# <a id="import"></a>
# <h2><b><span style="color:Green">🛒 Step 2.2 | </span><span style="color:Teal">Data Information</span></b></h2>

# %% [markdown]
# <div style="border-radius:50px; padding: 20px; font-size:100%; text-align:left; background-image: url(https://i.postimg.cc/65msrN7X/Black-and-Beige-Simple-Coming-Soon-Banner-1.png)">
#
#   <h2 style='border:5; border-radius: 15px; font-weight: 800; color:white; font-size:280%'>
#     <center>Attribute Information</center>
#   </h2>
#
#   <table style="font-family: Open Sans; font-weight: 300; font-size: 12px; text-align: left; padding: 8px; border-collapse: collapse; width: 100%;">
#     <thead>
#       <tr>
#         <th style="font-family: Open Sans; font-weight: 900; text-align: center; font-size: 14px; background-color: #FFA500">Column</th>
#         <th style="font-family: Open Sans; font-weight: 900; text-align: center; font-size: 14px; background-color: #FFA500">Feature-type</th>
#         <th style="font-family: Open Sans; font-weight: 900; text-align: center; font-size: 14px; background-color: #FFA500">Description</th>
#       </tr>
#     </thead>
#     <tbody>
#       <tr>
#         <td><b>InvoiceNo</b></td>
#         <td>String</td>
#         <td>Unique identifier for each transaction (invoice)</td>
#       </tr>
#       <tr>
#         <td><b>StockCode</b></td>
#         <td>String</td>
#         <td>Product/item code for the purchased goods</td>
#       </tr>
#       <tr>
#         <td><b>Description</b></td>
#         <td>String</td>
#         <td>Textual description of the product</td>
#       </tr>
#       <tr>
#         <td><b>Quantity</b></td>
#         <td>Integer</td>
#         <td>Number of items purchased per transaction line</td>
#       </tr>
#       <tr>
#         <td><b>InvoiceDate</b></td>
#         <td>DateTime</td>
#         <td>Date and time the transaction occurred</td>
#       </tr>
#       <tr>
#         <td><b>UnitPrice</b></td>
#         <td>Float</td>
#         <td>Price per single item (excluding tax)</td>
#       </tr>
#       <tr>
#         <td><b>CustomerID</b></td>
#         <td>String</td>
#         <td>Unique identifier for each customer (may be missing)</td>
#       </tr>
#       <tr>
#         <td><b>Country</b></td>
#         <td>String</td>
#         <td>Country where the customer resides or the transaction took place</td>
#       </tr>
#     </tbody>
#   </table>
# </div>

# %% [markdown]
# <a id="setup"></a>
# <h1><b><p style="background-image: url(https://i.postimg.cc/g2QJ9rCX/Black-and-Beige-Simple-Coming-Soon-Banner.png);font-family:tahoma;font-size:120%;color:White;text-align:center;border-radius:15px 50px; padding:7px; border:solid 2px #09375b; box-shadow: 10px 10px 10px #042b4c">Step 3| Exploratory Data Analysis</p></b></h1>

# %% [markdown]
# <a id="import"></a>
# <h2><b><span style="color:green">🛒 Step 3.1 | </span><span style="color:Teal">Descriptive Data</span></b></h2>

# %%
df.describe().T
# Out:
#                 count                           mean                  min  \
# Quantity     401604.0                      12.183273             -80995.0
# InvoiceDate    401604  2011-07-10 12:08:23.848567552  2010-12-01 08:26:00
# UnitPrice    401604.0                       3.474064                  0.0
#
#                              25%                  50%                  75%  \
# Quantity                     2.0                  5.0                 12.0
# InvoiceDate  2011-04-06 15:02:00  2011-07-29 15:40:00  2011-10-20 11:58:30
# UnitPrice                   1.25                 1.95                 3.75
#
#                              max         std
# Quantity                 80995.0  250.283037
# InvoiceDate  2011-12-09 12:50:00         NaN
# UnitPrice                38970.0   69.764035

# %% [markdown]
# <h2><b><span style="color:Teal">Summary statistics for categorical variables</span></b></h2>

# %%
df.describe(include='string').T
# Out:
#               count unique                                 top    freq
# InvoiceNo    401604  22190                              576339     542
# StockCode    401604   3684                              85123A    2065
# Description  401604   3896  WHITE HANGING HEART T-LIGHT HOLDER    2058
# CustomerID   401604   4372                               17841    7812
# Country      401604     37                      United Kingdom  356728

# %% [markdown]
# <h2><b><span style="color:Teal">Correlation Map</span></b></h2>

# %%
fnb_colors = ['#50C2C9', '#00887A', '#004D40']  
fnb_cmap = LinearSegmentedColormap.from_list("FNB_Teal", fnb_colors)
xy_label = {"fontsize": 12, "fontweight": "bold", "color": "#004D40"} 

# Filter to only numeric columns for correlation
numeric_df = df.select_dtypes(include='number')

fig, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(numeric_df.corr(), cmap=fnb_cmap, annot=True, fmt=".1f", linewidths=.5)

yticks, ylabels = plt.yticks()
xticks, xlabels = plt.xticks()

ax.set_xticklabels(xlabels, rotation=45, ha="right", **xy_label) 
ax.set_yticklabels(ylabels, **xy_label)

ax.grid(False)
plt.title('Correlation Map of the Numeric Data')
plt.show()

# %% [markdown]
# <h2><b><span style="color:Teal">Check Stock Codes</span></b></h2>

# %%
# Finding the number of unique stock codes
unique_stock_codes = df['StockCode'].nunique()

# Printing the number of unique stock codes
print(f"The number of unique stock codes in the dataset is: {unique_stock_codes}")
# Out:
# The number of unique stock codes in the dataset is: 3684

# %%
# Finding the top 10 most frequent stock codes
top_10_stock_codes = df['StockCode'].value_counts(normalize=True).head(10) * 100

# Plotting the top 10 most frequent stock codes
plt.figure(figsize=(12, 5))
top_10_stock_codes.plot(kind='barh', color='teal')

# Adding the percentage frequency on the bars
for index, value in enumerate(top_10_stock_codes):
    plt.text(value, index+0.25, f'{value:.2f}%', fontsize=10)

plt.title('Top 10 Most Frequent Stock Codes')
plt.xlabel('Percentage Frequency (%)')
plt.ylabel('Stock Codes')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# <h2><b><span style="color:Teal">Check Descriptions</span></b></h2>

# %%
# Calculate the occurrence of each unique description and sort them
description_counts = df['Description'].value_counts()

# Get the top 30 descriptions
top_30_descriptions = description_counts[:30]

# Plotting
plt.figure(figsize=(12,8))
plt.barh(top_30_descriptions.index[::-1], top_30_descriptions.values[::-1], color='teal')

# Adding labels and title
plt.xlabel('Number of Occurrences')
plt.ylabel('Description')
plt.title('Top 30 Most Frequent Descriptions')

# Show the plot
plt.show()

# %% [markdown]
# <h2><b><span style="color:Teal">Number of Days since the Last Purchase for each customer</span></b></h2>

# %%
# Convert InvoiceDate to datetime type
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Convert InvoiceDate to datetime and extract only the date
df['InvoiceDay'] = df['InvoiceDate'].dt.date

# Find the most recent purchase date for each customer
customer_datas = df.groupby('CustomerID')['InvoiceDay'].max().reset_index()

# Find the most recent date in the entire dataset
most_recent_date = df['InvoiceDay'].max()

# Convert InvoiceDay to datetime type before subtraction
customer_datas['InvoiceDay'] = pd.to_datetime(customer_datas['InvoiceDay'])
most_recent_date = pd.to_datetime(most_recent_date)

# Calculate the number of days since the last purchase for each customer
customer_datas['Days_Since_Last_Purchase'] = (most_recent_date - customer_datas['InvoiceDay']).dt.days

# Remove the InvoiceDay column
customer_datas.drop(columns=['InvoiceDay'], inplace=True)
customer_datas.head()
# Out:
#   CustomerID  Days_Since_Last_Purchase
# 0      12346                       325
# 1      12347                         2
# 2      12348                        75
# 3      12349                        18
# 4      12350                       310

# %% [markdown]
# <h2><b><span style="color:Teal">Number of Days since the Last Purchase, Total Number of transactions & Total Products Purchased and the Total Spent for each customer</span></b></h2>

# %%
# Calculate the total number of transactions made by each customer
total_transactionss = df.groupby('CustomerID')['InvoiceNo'].nunique().reset_index()
total_transactionss.rename(columns={'InvoiceNo': 'Total_Transactions'}, inplace=True)

# Calculate the total number of products purchased by each customer
total_products_purchasedd = df.groupby('CustomerID')['Quantity'].sum().reset_index()
total_products_purchasedd.rename(columns={'Quantity': 'Total_Products_Purchased'}, inplace=True)

# Drop existing columns in customer_data if they already exist
customer_datas = customer_datas.drop(columns=['Total_Transactions', 'Total_Products_Purchased'], errors='ignore')

# Merge new features into the customer_data dataframe
customer_datas = pd.merge(customer_datas, total_transactionss, on='CustomerID')
customer_data = pd.merge(customer_datas, total_products_purchasedd, on='CustomerID')

# Calculate the total spend by each customer
df['Total_Spend'] = df['UnitPrice'] * df['Quantity']
total_spent = df.groupby('CustomerID')['Total_Spend'].sum().reset_index()

# Drop if already present and merge total spend
customer_datas = customer_datas.drop(columns=['Total_Spend'], errors='ignore')
customer_datas = pd.merge(customer_datas, total_spent, on='CustomerID')


customer_datas.head()
# Out:
#   CustomerID  Days_Since_Last_Purchase  Total_Transactions  Total_Spend
# 0      12346                       325                   2         0.00
# 1      12347                         2                   7      4310.00
# 2      12348                        75                   4      1797.24
# 3      12349                        18                   1      1757.55
# 4      12350                       310                   1       334.40

# %%
sns.lineplot(data=customer_datas.sort_values('Days_Since_Last_Purchase'),
             x='Days_Since_Last_Purchase',
             y='Total_Spend')
plt.title('Spend vs Recency')
plt.xlabel('Days Since Last Purchase')
plt.ylabel('Total Spend')
plt.show()

# %% [markdown]
# <a id="import"></a>
# <h2><b><span style="color:green">🛒 Step 3.2 | </span><span style="color:Teal">Data Visualization</span></b></h2>

# %% [markdown]
# <h2><b><span style="color:teal"> Histograms</span></b></h2>

# %%
df.hist(figsize=(15,15),edgecolor='black');

# %% [markdown]
# <h2><b><span style="color:teal"> Pair Plots for overall Cumstomer Matrics</span></b></h2>

# %%
sns.pairplot(customer_datas[['Days_Since_Last_Purchase', 'Total_Transactions', 'Total_Spend']])
plt.suptitle('Pair Plot of Customer Metrics', y=1.02)
plt.show()

# %% [markdown]
# <h2><b><span style="color:teal"> Top 10 Customers by Spending</span></b></h2>

# %%
top_customers = customer_datas.sort_values(by='Total_Spend', ascending=False).head(10)

sns.barplot(data=top_customers, x='CustomerID', y='Total_Spend', palette='viridis')
plt.title('Top 10 Customers by Spend')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\reabetswe.malatji\AppData\Local\Temp\ipykernel_27564\4238851995.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top_customers, x='CustomerID', y='Total_Spend', palette='viridis')

# %% [markdown]
# <h2><b><span style="color:teal"> Top 10 Selling Products</span></b></h2>

# %%
top_products = df.groupby('Description')['Quantity'].sum().sort_values(ascending=False).head(10)

top_products.plot(kind='bar', figsize=(12,6), color='#00887A')
plt.title('Top 10 Selling Products')
plt.ylabel('Total Quantity Sold')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# <a id="setup"></a>
# <h1><b><p style="background-image: url(https://i.postimg.cc/g2QJ9rCX/Black-and-Beige-Simple-Coming-Soon-Banner.png);font-family:tahoma;font-size:120%;color:White;text-align:center;border-radius:15px 50px; padding:7px; border:solid 2px #09375b; box-shadow: 10px 10px 10px #042b4c">Step 4| Data Preparation</p></b></h1>

# %% [markdown]
# <a id="import"></a>
# <h2><b><span style="color:green">🛒 Step 4.1 | </span><span style="color:Teal"> Data pre-processing</span></b></h2>

# %% [markdown]
# <h2><b><span style="color:teal"> SVD Data Prep </span></b></h2>

# %%
user_item_matrix = df.pivot_table(index='CustomerID', columns='StockCode', values='Quantity', aggfunc='sum').fillna(0)

# %% [markdown]
# <h2><b><span style="color:teal"> ALS Data Prep </span></b></h2>

# %%
# Create a user-item matrix with total quantity or spend
df['CustomerID'] = df['CustomerID'].astype(str)
df['Total_Spend'] = df['UnitPrice'] * df['Quantity']

# Create mappings for ALS 
user_map = {user: idx for idx, user in enumerate(df['CustomerID'].unique())}
item_map = {item: idx for idx, item in enumerate(df['StockCode'].unique())}

df['user_id'] = df['CustomerID'].map(user_map)
df['item_id'] = df['StockCode'].map(item_map)

# Create sparse matrix: rows = items, columns = users
item_user_matrix = sparse.coo_matrix(
    (df['Total_Spend'], (df['item_id'], df['user_id']))
).tocsr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 13
#      10 df['item_id'] = df['StockCode'].map(item_map)
#      12 # Create sparse matrix: rows = items, columns = users
# ---> 13 item_user_matrix = sparse.coo_matrix(
#      14     (df['Total_Spend'], (df['item_id'], df['user_id']))
#      15 ).tocsr()
#
# NameError: name 'sparse' is not defined

# %% [markdown]
# <h2><b><span style="color:teal">Train Random Forest </span></b></h2>

# %%
df['Affordable'] = (df['UnitPrice'] < df['UnitPrice'].median()).astype(int)

#Define features (X) and target (y)
X = df[['Quantity']]  # You can add more features later
y = df['Affordable']

#Split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# <a id="setup"></a>
# <h1><b><p style="background-image: url(https://i.postimg.cc/g2QJ9rCX/Black-and-Beige-Simple-Coming-Soon-Banner.png);font-family:tahoma;font-size:120%;color:White;text-align:center;border-radius:15px 50px; padding:7px; border:solid 2px #09375b; box-shadow: 10px 10px 10px #042b4c">Step 5| Model Selection</p></b></h1>

# %% [markdown]
# <a id="import"></a>
# <h2><b><span style="color:green">🛒 Step 5.1 | </span><span style="color:Teal">Implement Models</span></b></h2>

# %% [markdown]
# <h2><b><span style="color:teal"> 👩🏽‍💻 SVD</span></b></h2>

# %%
df['Total_Spend'] = df['Quantity'] * df['UnitPrice']
reader = Reader(rating_scale=(df['Total_Spend'].min(), df['Total_Spend'].max()))
data = Dataset.load_from_df(df[['CustomerID', 'StockCode', 'Total_Spend']], reader)

algo = SVD()
cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 from surprise import SVD, Dataset, Reader
#       2 from surprise.model_selection import cross_validate
#       4 # Prepare data for Surprise
#
# ModuleNotFoundError: No module named 'surprise'

# %% [markdown]
# <h2><b><span style="color:teal"> 👩🏽‍💻 ALS</span></b></h2>

# %%
model = AlternatingLeastSquares(
    factors=50,
    regularization=0.01,
    iterations=15,
    use_gpu=False  # Set to True if you have CUDA-capable GPU
)

# The implicit library expects "confidence" data: you may scale up
item_user_matrix *= 5

# Fit the model
model.fit(item_user_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 model = AlternatingLeastSquares(
#       2     factors=50,
#       3     regularization=0.01,
#       4     iterations=15,
#       5     use_gpu=False  # Set to True if you have CUDA-capable GPU
#       6 )
#       8 # The implicit library expects "confidence" data: you may scale up
#       9 item_user_matrix *= 5
#
# NameError: name 'AlternatingLeastSquares' is not defined

# %% [markdown]
# <h2><b><span style="color:teal"> ALS Recommendations</span></b></h2>

# %%
# Recommend top 5 items for user_id 0
user_id = 0
recommended = model.recommend(user_id, item_user_matrix.T, N=5)

# Map back item IDs
reverse_item_map = {idx: item for item, idx in item_map.items()}
recommended_items = [(reverse_item_map[i], score) for i, score in recommended]

print("Top 5 recommendations for User 0:")
print(recommended_items)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[93], line 3
#       1 # Recommend top 5 items for user_id 0
#       2 user_id = 0
# ----> 3 recommended = model.recommend(user_id, item_user_matrix.T, N=5)
#       5 # Map back item IDs
#       6 reverse_item_map = {idx: item for item, idx in item_map.items()}
#
# NameError: name 'model' is not defined

# %% [markdown]
# <h2><b><span style="color:teal"> 👩🏽‍💻 Random Forest</span></b></h2>

# %%
#Train the Random Forest model
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)

#Predict and evaluate
y_pred = rf.predict(X_test)
print("Random Forest Affordability Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Random Forest Affordability Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.81      0.73     61061
#            1       0.75      0.58      0.65     59421
#
#     accuracy                           0.70    120482
#    macro avg       0.71      0.69      0.69    120482
# weighted avg       0.70      0.70      0.69    120482

# %% [markdown]
# <h2><b><span style="color:teal"> 👩🏽‍💻 Cosine: Based on Product Description</span></b></h2>

# %%
# Remove duplicates and missing descriptions
item_df = df[['StockCode', 'Description']].dropna().drop_duplicates()

# Vectorize item descriptions using TF-IDF
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(item_df['Description'])

# Compute cosine similarity between all item descriptions
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Function to get top N similar items
def get_similar_items(item_description, top_n=5):
    # Find index of the item
    indices = pd.Series(item_df.index, index=item_df['Description']).drop_duplicates()
    idx = indices.get(item_description)

    if idx is None:
        print("Item not found.")
        return []

    # Get similarity scores
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:top_n+1]  # exclude the item itself

    similar_items = item_df.iloc[[i[0] for i in sim_scores]]
    return similar_items

# Here I used an Example usage
get_similar_items("WHITE HANGING HEART T-LIGHT HOLDER", top_n=5)
# Out:
#        StockCode                         Description
# 396548     22804   PINK HANGING HEART T-LIGHT HOLDER
# 83         21733    RED HANGING HEART T-LIGHT HOLDER
# 537621    85123A  CREAM HANGING HEART T-LIGHT HOLDER
# 217       84970S   HANGING HEART ZINC T-LIGHT HOLDER
# 816        21814               HEART T-LIGHT HOLDER

# %% [markdown]
# #### Interpretation
#
# ##### - These are items that have similar product descriptions, likely visually or functionally similar.
#
# ##### - The model used the Description text and compared them based on linguistic content.
#
# ##### - It's ideal for new users/items when no purchase history is available (cold start)

# %% [markdown]
# <h2><b><span style="color:teal"> 👩🏽‍💻 Cosine: Based on User Item Matrix </span></b></h2>

# %%
# Create item-user matrix (products x customers)
item_user_matrix = df.pivot_table(index='StockCode', columns='CustomerID', values='Quantity', aggfunc='sum', fill_value=0)

# Compute cosine similarity between items
item_similarity = cosine_similarity(item_user_matrix)
item_sim_df = pd.DataFrame(item_similarity, index=item_user_matrix.index, columns=item_user_matrix.index)

# Function to get similar items based on purchases
def recommend_similar_items(stock_code, top_n=5):
    if stock_code not in item_sim_df.index:
        print("Item not found.")
        return []

    similar_items = item_sim_df[stock_code].sort_values(ascending=False)[1:top_n+1]
    return similar_items

# Here I used an example usage
recommend_similar_items('85123A')
# Out:
# StockCode
# 21733    0.790045
# 82552    0.772382
# 82551    0.770578
# 23288    0.756849
# 23286    0.755860
# Name: 85123A, dtype: float64

# %% [markdown]
# #### Interpretation
#
# ##### - These are items that were frequently bought by the same customers who bought 85123A.
#
# ##### - Cosine similarity compares vectors of quantities per customer across items.
#
# ##### - It's behavior-driven: if customers often buy A and B together, they’re marked as similar.
#
# ##### - Great for capturing actual user preferences and demand trends.

# %% [markdown]
# <h2><b><span style="color:teal"> Cross-Validation</span></b></h2>

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(rf, X, y, cv=5, scoring='accuracy')
print("Cross-validated accuracy:", scores.mean())
# Out:
# Cross-validated accuracy: 0.6976871775791966

# %% [markdown]
# <h2><b><span style="color:teal"> Confusion Matrix </span></b></h2>

# %%
rf_preds = rf.predict(X_test)

# Compute the confusion matrix
cm = confusion_matrix(y_test, rf_preds)

# Display with class labels
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=["Not Affordable", "Affordable"])
disp.plot(cmap="Greens")
plt.title("Confusion Matrix - Random Forest Affordability Prediction")
plt.show()

# %% [markdown]
# <h2><b><span style="color:teal"> Random Forest Performance </span></b></h2>

# %%
calibrated_rf = CalibratedClassifierCV(rf, method='sigmoid')
calibrated_rf.fit(X_train, y_train)
calibrated_probs = calibrated_rf.predict_proba(X_test)[:, 1]

# %%
sns.histplot(calibrated_probs, bins=20, kde=True, color="teal")
plt.title("Calibrated Probability of Being Affordable")
plt.xlabel("Probability")
plt.ylabel("Frequency")
plt.show()

# %%
from sklearn.metrics import roc_auc_score, log_loss

print("ROC AUC Score:", roc_auc_score(y_test, calibrated_probs))
print("Log Loss:", log_loss(y_test, calibrated_probs))
# Out:
# ROC AUC Score: 0.7325493945888955
# Log Loss: 0.594987647068919

# %% [markdown]
# | Metric   | Value  | Meaning                                                              |
# | -------- | ------ | -------------------------------------------------------------------- |
# | ROC AUC  | 0.7325 | The model distinguishes well between the two classes                |
# | Log Loss | 0.595  | The probability predictions are decent but not perfectly calibrated |

# %% [markdown]
# <a id="import"></a>
# <h2><b><span style="color:green">🛒 Step 5.2 | </span><span style="color:Teal">Model Comparisons</span></b></h2>

# %% [markdown]
# <h2><b><span style="color:teal"> Table of Results </span></b></h2>

# %% [markdown]
# | Model Type        | Accuracy Metrics            | Beyond-Accuracy Metrics                 |
# | ----------------- | --------------------------- | --------------------------------------- |
# | SVD / ALS         | RMSE, MAE (from test set)   | Precision\@k, Recall\@k, NDCG, Hit Rate |
# | Random Forest     | Accuracy, ROC AUC, F1-score | Calibrated Probabilities, Log Loss      |
# | Cosine Similarity | N/A (no training phase)     | Top-N Recommendations + Hit Rate or MAP |

# %% [markdown]
# <a id="setup"></a>
# <h1><b><p style="background-image: url(https://i.postimg.cc/g2QJ9rCX/Black-and-Beige-Simple-Coming-Soon-Banner.png);font-family:tahoma;font-size:120%;color:White;text-align:center;border-radius:15px 50px; padding:7px; border:solid 2px #09375b; box-shadow: 10px 10px 10px #042b4c">Step 6| Hybrid Model</p></b></h1>

# %% [markdown]
# <a id="import"></a>
# <h2><b><span style="color:green">🛒 Step 5.2 | </span><span style="color:Teal">Recommendation: Hybrid Model</span></b></h2>

# %%
def svd_recommend(user_id, top_n=20):
    user_items = df[df['CustomerID'] == user_id]['StockCode'].unique()
    all_items = df['StockCode'].unique()
    items_to_score = [item for item in all_items if item not in user_items]

    predictions = [
        (item, svd_model.predict(user_id, item).est) for item in items_to_score
    ]
    top_items = sorted(predictions, key=lambda x: x[1], reverse=True)[:top_n]
    return [item for item, _ in top_items]


def random_forest_filter(item_list):
    item_data = df[df['StockCode'].isin(item_list)][['StockCode', 'Quantity']].drop_duplicates()
    affordability_predictions = rf_model.predict(item_data[['Quantity']])
    item_data['Affordable'] = affordability_predictions
    affordable_items = item_data[item_data['Affordable'] == 1]['StockCode'].tolist()
    return affordable_items


def diversify_with_cosine(item_list, top_k=3):
    diverse_items = set()
    for item in item_list:
        if item in cosine_sim_matrix.index:
            similar_items = cosine_sim_matrix.loc[item].sort_values(ascending=False)
            similar_items = similar_items[similar_items.index != item][:top_k]
            diverse_items.update(similar_items.index.tolist())
    return list(diverse_items)


def hybrid_recommender(user_id):
    svd_items = svd_recommend(user_id)
    affordable_items = random_forest_filter(svd_items)
    diverse_items = diversify_with_cosine(affordable_items)
    hybrid_recommendations = list(set(affordable_items + diverse_items))
    return hybrid_recommendations

# %% [markdown]
# <h2><b><span style="color:teal"> Example </span></b></h2>

# %%
user_id = 12347
recommendations = hybrid_recommender(user_id)
print("Hybrid Recommendations for User", user_id)
print(recommendations)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[146], line 2
#       1 user_id = 12347
# ----> 2 recommendations = hybrid_recommender(user_id)
#       3 print("Hybrid Recommendations for User", user_id)
#       4 print(recommendations)
#
# Cell In[143], line 32, in hybrid_recommender(user_id)
#      31 def hybrid_recommender(user_id):
# ---> 32     svd_items = svd_recommend(user_id)
#      33     affordable_items = random_forest_filter(svd_items)
#      34     diverse_items = diversify_with_cosine(affordable_items)
#
# Cell In[143], line 7, in svd_recommend(user_id, top_n)
#       3 all_items = df['StockCode'].unique()
#       4 items_to_score = [item for item in all_items if item not in user_items]
#       6 predictions = [
# ----> 7     (item, svd_model.predict(user_id, item).est) for item in items_to_score
#       8 ]
# ...
